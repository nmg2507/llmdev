# %% [markdown]
# 課題：スクレイピングを業務で活用するアイデア

# %% [markdown]
# 今は人事で人材育成・組織開発の仕事をしています。スクレイピングの活用例を考えました。
#
# 目的：他社の取り組みや最新トレンドを効率よく情報収集・共有し、数年先の動きを見据えた人材育成体制の一助とする
#
# スクレイピング情報収集対象例：
# （経済産業省未来人材ビジョン）https://www.meti.go.jp/press/2022/05/20220531001/20220531001-1.pdf
# （日本の人事部）https://jinjibu.jp/tag/?new=
# 　*Google-CloudVertexBot 等を使う必要
# （PRタイムス・人材育成プレスリリース）https://prtimes.jp/topics/keywords/%E4%BA%BA%E6%9D%90%E8%82%B2%E6%88%90
# 　*feedperserライブラリ利用も検討
#
# 上記3種の情報例（数年先の人材育成の方向性 × 外部の育成事例や手法のトレンド）と、
# 可能であれば現在の自社の現状(構造化したもの)をもとに言語モデルで分析を行い、
# 次の施策を考える材料とします。

# %% [markdown]
# コードはありません
